# %%
import pandas as pd 
import numpy  as np 
import re

# %%
data = pd.read_csv(r"BL-Flickr-Images-Book.csv")
data.head
# Out:
# <bound method NDFrame.head of       Identifier             Edition Statement      Place of Publication  \
# 0            206                           NaN                    London
# 1            216                           NaN  London; Virtue & Yorston
# 2            218                           NaN                    London
# 3            472                           NaN                    London
# 4            480  A new edition, revised, etc.                    London
# ...          ...                           ...                       ...
# 8282     4158088                           NaN                    London
# 8283     4158128                           NaN                     Derby
# 8284     4159563                           NaN                    London
# 8285     4159587                           NaN       Newcastle upon Tyne
# 8286     4160339                           NaN                    London
#
#      Date of Publication                Publisher  \
# ...

# %%
data.columns
# Out:
# Index(['Identifier', 'Edition Statement', 'Place of Publication',
#        'Date of Publication', 'Publisher', 'Title', 'Author', 'Contributors',
#        'Corporate Author', 'Corporate Contributors', 'Former owner',
#        'Engraver', 'Issuance type', 'Flickr URL', 'Shelfmarks'],
#       dtype='object')

# %%
to_drop = ['Former owner', 'Edition Statement', 'Engraver', 'Issuance type', 'Corporate Author', 'Corporate Contributors', 'Shelfmarks']
data1 = data.copy()

# %%
data1 = data1.drop(columns=to_drop)
data1
# Out:
#       Identifier      Place of Publication Date of Publication  \
# 0            206                    London         1879 [1878]
# 1            216  London; Virtue & Yorston                1868
# 2            218                    London                1869
# 3            472                    London                1851
# 4            480                    London                1857
# ...          ...                       ...                 ...
# 8282     4158088                    London                1838
# 8283     4158128                     Derby            1831, 32
# 8284     4159563                    London           [1806]-22
# 8285     4159587       Newcastle upon Tyne                1834
# 8286     4160339                    London             1834-43
#
#                     Publisher  \
# 0            S. Tinsley & Co.
# 1                Virtue & Co.
# 2       Bradbury, Evans & Co.
# 3               James Darling
# 4        Wertheim & Macintosh
# ...

# %%
data2 = data1.set_index('Identifier')
data2
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London         1879 [1878]
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
# 472                           London                1851
# 480                           London                1857
# ...                              ...                 ...
# 4158088                       London                1838
# 4158128                        Derby            1831, 32
# 4159563                       London           [1806]-22
# 4159587          Newcastle upon Tyne                1834
# 4160339                       London             1834-43
#
#                           Publisher  \
# Identifier
# 206                S. Tinsley & Co.
# 216                    Virtue & Co.
# 218           Bradbury, Evans & Co.
# 472                   James Darling
# 480            Wertheim & Macintosh
# ...

# %%
newColumn = data2['Date of Publication'].str.extract(r'^(\d{4})', expand=False)
newColumn
# Out:
# Identifier
# 206        1879
# 216        1868
# 218        1869
# 472        1851
# 480        1857
#            ...
# 4158088    1838
# 4158128    1831
# 4159563     NaN
# 4159587    1834
# 4160339    1834
# Name: Date of Publication, Length: 8287, dtype: object

# %%
data2['Date of Publication'] = pd.to_numeric(newColumn)
data2
# Out:
#                 Place of Publication  Date of Publication  \
# Identifier
# 206                           London               1879.0
# 216         London; Virtue & Yorston               1868.0
# 218                           London               1869.0
# 472                           London               1851.0
# 480                           London               1857.0
# ...                              ...                  ...
# 4158088                       London               1838.0
# 4158128                        Derby               1831.0
# 4159563                       London                  NaN
# 4159587          Newcastle upon Tyne               1834.0
# 4160339                       London               1834.0
#
#                           Publisher  \
# Identifier
# 206                S. Tinsley & Co.
# 216                    Virtue & Co.
# 218           Bradbury, Evans & Co.
# 472                   James Darling
# 480            Wertheim & Macintosh
# ...

# %%
place = data2['Place of Publication']
london = place.str.contains('London')
london
# Out:
# Identifier
# 206         True
# 216         True
# 218         True
# 472         True
# 480         True
#            ...
# 4158088     True
# 4158128    False
# 4159563     True
# 4159587    False
# 4160339     True
# Name: Place of Publication, Length: 8287, dtype: bool

# %%
oxford = place.str.contains("Oxford")

# %%
data2['Place of Publication'] = np.where(london, 'London',
                                      np.where(oxford, 'Oxford',
                                               place.str.replace('-', ' ')))

# %%
unwanted_characters = ['[', ',', '-',']']
def clean_dates(item):
    dop = item.get('Date of Publication')  # Safe way to access column data
    if pd.isna(dop):  # Handle actual NaN
        return np.NaN
    
    dop = str(dop)
    if dop.startswith('['):  # Check for unwanted start
        dop = dop[1:]
    
    for character in unwanted_characters:
        dop = dop.split(character)[0]  # Split on the character and take the first part
    
    return dop.strip()  # Clean trailing spaces

# Apply function to the DataFrame
data2['Date of Publication'] = data2.apply(clean_dates, axis=1)
data2
# Out:
#            Place of Publication Date of Publication                Publisher  \
# Identifier
# 206                      London              1879.0         S. Tinsley & Co.
# 216                      London              1868.0             Virtue & Co.
# 218                      London              1869.0    Bradbury, Evans & Co.
# 472                      London              1851.0            James Darling
# 480                      London              1857.0     Wertheim & Macintosh
# ...                         ...                 ...                      ...
# 4158088                  London              1838.0                      NaN
# 4158128                   Derby              1831.0          M. Mozley & Son
# 4159563                  London                 NaN  T. Cadell and W. Davies
# 4159587     Newcastle upon Tyne              1834.0         Mackenzie & Dent
# 4160339                  London              1834.0                      NaN
#
# ...

# %%
def clean_author_names(author):
    # Handle missing values
    if pd.isna(author):
        return 'NaN'
    
    # Convert to string
    author = str(author).strip()
    
    # Handle 'nan' as a string
    if author.lower() == 'nan':
        return 'NaN'
    
    # Split by comma
    parts = author.split(',')
    
    # If no comma, assume it's a single name
    if len(parts) == 1:
        name = parts[0]
        # Remove special characters but preserve spaces and hyphens
        name = re.sub(r'[^a-zA-Z\s-]', '', name)
        return name.strip()
    
    # Extract last name and first name
    last_name, first_name = parts[0].strip(), parts[1].strip()
    
    # Clean first name
    # Remove anything after a hyphen (optional, depending on your needs)
    if '-' in first_name:
        first_name = first_name[:first_name.find('-')]
    
    # Remove trailing periods or special characters
    first_name = re.sub(r'[\.\|]+$', '', first_name)
    
    # Capitalize last name
    last_name = last_name.capitalize()
    
    # Combine and return
    return f'{first_name.strip()} {last_name.strip()}'

# Apply the function to the DataFrame
data2['Author'] = data2['Author'].apply(clean_author_names)
data2
# Out:
#            Place of Publication Date of Publication                Publisher  \
# Identifier
# 206                      London              1879.0         S. Tinsley & Co.
# 216                      London              1868.0             Virtue & Co.
# 218                      London              1869.0    Bradbury, Evans & Co.
# 472                      London              1851.0            James Darling
# 480                      London              1857.0     Wertheim & Macintosh
# ...                         ...                 ...                      ...
# 4158088                  London              1838.0                      NaN
# 4158128                   Derby              1831.0          M. Mozley & Son
# 4159563                  London                 NaN  T. Cadell and W. Davies
# 4159587     Newcastle upon Tyne              1834.0         Mackenzie & Dent
# 4160339                  London              1834.0                      NaN
#
# ...

# %%
def clean_title(title):
    # Handle missing values
    if pd.isna(title):
        return 'NaN'
    
    # Convert to string
    title = str(title).strip()
    
    # Handle 'nan' as a string
    if title.lower() == 'nan':
        return 'NaN'
    
    # Remove content inside brackets
    if title.startswith('['):
        title = title[1:title.find(']')]
    
    # Remove everything after 'by' or 'By' (case-insensitive)
    by_index = title.lower().find('by')
    if by_index != -1:
        title = title[:by_index].strip()
    
    # Remove additional bracketed content
    bracket_index = title.find('[')
    if bracket_index != -1:
        title = title[:bracket_index].strip()
    
    # Remove trailing special characters (optional)
    title = title.strip('.,!?;:- ')
    
    # Capitalize words (using title() for better formatting)
    title = title.title()
    
    return title

# Apply the function to the DataFrame
data2['Title'] = data2['Title'].apply(clean_title)
data2.head()
# Out:
#            Place of Publication Date of Publication              Publisher  \
# Identifier
# 206                      London              1879.0       S. Tinsley & Co.
# 216                      London              1868.0           Virtue & Co.
# 218                      London              1869.0  Bradbury, Evans & Co.
# 472                      London              1851.0          James Darling
# 480                      London              1857.0   Wertheim & Macintosh
#
#                                                         Title   Author  \
# Identifier
# 206                                             Walter Forbes      A A
# 216                                             All For Greed  A. A A.
# 218                                          Love The Avenger  A. A A.
# 472         Welsh Sketches, Chiefly Ecclesiastical, To The...  E. S A.
# 480             The World In Which I Live, And My Place In It  E. S A.
#
#                                             Contributors  \
# ...

# %%
# Define a dictionary of replacements
place_mapping = {
    r'(?i)london': 'London',  # (?i) makes the regex case-insensitive
    r'(?i)oxford': 'Oxford',
    r'(?i)newcastle upon tyne': 'Newcastle-upon-Tyne'
}

# Use replace() with regex=True
data2['Place of Publication'] = data2['Place of Publication'].replace(place_mapping, regex=True)
data2
# Out:
#            Place of Publication Date of Publication                Publisher  \
# Identifier
# 206                      London              1879.0         S. Tinsley & Co.
# 216                      London              1868.0             Virtue & Co.
# 218                      London              1869.0    Bradbury, Evans & Co.
# 472                      London              1851.0            James Darling
# 480                      London              1857.0     Wertheim & Macintosh
# ...                         ...                 ...                      ...
# 4158088                  London              1838.0                      NaN
# 4158128                   Derby              1831.0          M. Mozley & Son
# 4159563                  London                 NaN  T. Cadell and W. Davies
# 4159587     Newcastle-upon-Tyne              1834.0         Mackenzie & Dent
# 4160339                  London              1834.0                      NaN
#
# ...

# %%
data2.to_csv("Final output.csv" ,index=False)
